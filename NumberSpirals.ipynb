# %% [markdown]
# Original Code that I realised after gives an incorrect result

# %%
import matplotlib.pyplot as plt
import numpy as np

def Prime(n):
    if n == 1:
        return False
    if n == 2:
        return True
    if n % 2 == 0:  
        return False
    if n % 3 == 0:
        return False
    f = 5
    while f**2 <= n:
        if n % f == 0 or n % (f+2) == 0:
            return False
        f += 6
    return True

def Count(array):
    count = 0
    for n in array:
        if Prime(n):
            count += 1
    return count

def Corner4(n):
    return n**2

x = 10

array4 = []
for i in range(1,x+1):
    C4 = Corner4(i)
    array4.append(C4)

print(array4)
print(Count(array4))
print(Count(array4) / len(array4)*100)

def Corner3(n):
    return n**2 - 1*(n-1)

array3 = []
for i in range(1,x+1):
    C3 = Corner3(i)
    array3.append(C3)

print(array3)
print(Count(array3))
print(Count(array3) / len(array3)*100)

def Corner2(n):
    return n**2 - 2*(n-1)

array2 = []
for i in range(1,x+1):
    C2 = Corner2(i)
    array2.append(C2)

print(array2)
print(Count(array2))
print(Count(array2) / len(array2)*100)

def Corner1(n):
    return n**2 - 3*(n-1)

array1 = []
for i in range(1,x+1):
    C1 = Corner1(i)
    array1.append(C1)

print(array1)
print(Count(array1))
print(Count(array1) / len(array1)*100)

corners = ['C1', 'C2', 'C3', 'C4']
percents = [Count(array1) / len(array1)*100, Count(array2) / len(array2)*100, Count(array3) / len(array3)*100, Count(array4) / len(array4)*100]

plt.bar(corners, percents, color='skyblue')
plt.xlabel('Corners')
plt.ylabel('Percentage of Prime Numbers')
plt.title('Percentage of Prime Numbers in Each Corner from S_1 to S_10')
plt.ylim(0, 100)
plt.show()
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# 0
# 0.0
# [1, 3, 7, 13, 21, 31, 43, 57, 73, 91]
# 5
# 50.0
# [1, 2, 5, 10, 17, 26, 37, 50, 65, 82]
# 4
# 40.0
# [1, 1, 3, 7, 13, 21, 31, 43, 57, 73]
# 5
# 50.0

# %% [markdown]
# Corrected code after stuck stage in my rubric

# %%
import matplotlib.pyplot as plt
import numpy as np

def Prime(n):
    if n == 1:
        return False
    if n == 2:
        return True
    if n % 2 == 0:  
        return False
    if n % 3 == 0:
        return False
    f = 5
    while f**2 <= n:
        if n % f == 0 or n % (f+2) == 0:
            return False
        f += 6
    return True

def Count(array):
    count = 0
    for n in array:
        if Prime(n):
            count += 1
    return count

def Corner4(n):
    if n % 2 == 0:
        return n**2
    else:
        return n**2 - 2*(n-1)

x = 10

array4 = []
for i in range(1,x+1):
    C4 = Corner4(i)
    array4.append(C4)

print(array4)
print(Count(array4))
print(Count(array4) / len(array4)*100)

def Corner3(n):
    if n % 2 == 0:
        return n**2 - 1*(n-1)
    else:
        return n**2 - 3*(n-1)

array3 = []
for i in range(1,x+1):
    C3 = Corner3(i)
    array3.append(C3)

print(array3)
print(Count(array3))
print(Count(array3) / len(array3)*100)

def Corner2(n):
    if n % 2 == 0:
        return n**2 - 2*(n-1)
    else:
        return n**2

array2 = []
for i in range(1,x+1):
    C2 = Corner2(i)
    array2.append(C2)

print(array2)
print(Count(array2))
print(Count(array2) / len(array2)*100)

def Corner1(n):
    if n % 2 == 0:
        return n**2 - 3*(n-1)
    else:
        return n**2 - 1*(n-1)

array1 = []
for i in range(1,x+1):
    C1 = Corner1(i)
    array1.append(C1)

print(array1)
print(Count(array1))
print(Count(array1) / len(array1)*100)

corners = ['C1', 'C2', 'C3', 'C4']
percents = [Count(array1) / len(array1)*100, Count(array2) / len(array2)*100, Count(array3) / len(array3)*100, Count(array4) / len(array4)*100]

plt.bar(corners, percents, color='skyblue')
plt.xlabel('Corners')
plt.ylabel('Percentage of Prime Numbers')
plt.title('Percentage of Prime Numbers in Each Corner from S_1 to S_10')
plt.ylim(0, 100)
plt.show()
# Out:
# [1, 4, 5, 16, 17, 36, 37, 64, 65, 100]
# 3
# 30.0
# [1, 3, 3, 13, 13, 31, 31, 57, 57, 91]
# 4
# 40.0
# [1, 2, 9, 10, 25, 26, 49, 50, 81, 82]
# 1
# 10.0
# [1, 1, 7, 7, 21, 21, 43, 43, 73, 73]
# 6
# 60.0

# %% [markdown]
# Code for the Extend part of the rubric

# %%
import matplotlib.pyplot as plt
import numpy as np

def Prime(n):
    if n == 1:
        return False
    if n == 2:
        return True
    if n % 2 == 0:  
        return False
    if n % 3 == 0:
        return False
    f = 5
    while f**2 <= n:
        if n % f == 0 or n % (f+2) == 0:
            return False
        f += 6
    return True

def Count(array):
    count = 0
    for n in array:
        if Prime(n):
            count += 1
    return count

def Corner4(n):
    if n % 2 == 0:
        return n**2
    else:
        return n**2 - 2*(n-1)

x = 100

array4 = []
for i in range(1,x+1,2):
    C4 = Corner4(i)
    array4.append(C4)

print(array4)
print(Count(array4))
print(Count(array4) / len(array4)*100)

def Corner3(n):
    if n % 2 == 0:
        return n**2 - 1*(n-1)
    else:
        return n**2 - 3*(n-1)

array3 = []
for i in range(1,x+1,2):
    C3 = Corner3(i)
    array3.append(C3)

print(array3)
print(Count(array3))
print(Count(array3) / len(array3)*100)

def Corner2(n):
    if n % 2 == 0:
        return n**2 - 2*(n-1)
    else:
        return n**2

array2 = []
for i in range(1,x+1,2):
    C2 = Corner2(i)
    array2.append(C2)

print(array2)
print(Count(array2))
print(Count(array2) / len(array2)*100)

def Corner1(n):
    if n % 2 == 0:
        return n**2 - 3*(n-1)
    else:
        return n**2 - 1*(n-1)

array1 = []
for i in range(1,x+1,2):
    C1 = Corner1(i)
    array1.append(C1)

print(array1)
print(Count(array1))
print(Count(array1) / len(array1)*100)

corners = ['C1', 'C2', 'C3', 'C4']
percents = [Count(array1) / len(array1)*100, Count(array2) / len(array2)*100, Count(array3) / len(array3)*100, Count(array4) / len(array4)*100]

plt.bar(corners, percents, color='skyblue')
plt.xlabel('Corners')
plt.ylabel('Percentage of Prime Numbers')
plt.title('Percentage of Prime Numbers in Each Corner from S_1 to S_100')
plt.ylim(0, 100)
plt.show()
# Out:
# [1, 5, 17, 37, 65, 101, 145, 197, 257, 325, 401, 485, 577, 677, 785, 901, 1025, 1157, 1297, 1445, 1601, 1765, 1937, 2117, 2305, 2501, 2705, 2917, 3137, 3365, 3601, 3845, 4097, 4357, 4625, 4901, 5185, 5477, 5777, 6085, 6401, 6725, 7057, 7397, 7745, 8101, 8465, 8837, 9217, 9605]
# 18
# 36.0
# [1, 3, 13, 31, 57, 91, 133, 183, 241, 307, 381, 463, 553, 651, 757, 871, 993, 1123, 1261, 1407, 1561, 1723, 1893, 2071, 2257, 2451, 2653, 2863, 3081, 3307, 3541, 3783, 4033, 4291, 4557, 4831, 5113, 5403, 5701, 6007, 6321, 6643, 6973, 7311, 7657, 8011, 8373, 8743, 9121, 9507]
# 15
# 30.0
# [1, 9, 25, 49, 81, 121, 169, 225, 289, 361, 441, 529, 625, 729, 841, 961, 1089, 1225, 1369, 1521, 1681, 1849, 2025, 2209, 2401, 2601, 2809, 3025, 3249, 3481, 3721, 3969, 4225, 4489, 4761, 5041, 5329, 5625, 5929, 6241, 6561, 6889, 7225, 7569, 7921, 8281, 8649, 9025, 9409, 9801]
# 0
# 0.0
# ...
